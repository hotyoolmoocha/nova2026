# %%
import matplotlib as mat
import matplotlib.pyplot as plt

mat.__version__
# Out:
# '3.10.0'

# %%
import numpy as np

x = np.array([1,2,3,4,5])
y = np.log(x)

# %%
plt.plot(x,y)
plt.title("Title - Log")
plt.xlabel("Number")
plt.ylabel("Option")
plt.show()

# %%
fig, ax = plt.subplots()
