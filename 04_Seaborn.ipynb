# %%
import seaborn as sns

sns.__version__
# Out:
# '0.13.2'

# %%
sns.scatterplot(x ="total_bill", y = "tip",

# %% [markdown]
# ##Line Plot

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot(xlabel="day",ylabel = "total_bill")
# Out:
# <Axes: >
